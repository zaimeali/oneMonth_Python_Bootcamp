# %% [markdown]
# # import Pandas

# %%
import pandas as pd

# %% [markdown]
# # import Data

# %%
header = ['id', 'title', 'year', 'rating', 'votes', 'length', 'genres']
# index_col = 0 will make the first row as id
data = pd.read_csv('imdb_top_10000.txt', sep = '\t', names = header, index_col = 0)

# %% [markdown]
# # Explore Data

# %%
data.head(10)
# Out:
#                                                        title  year  rating  \
# id
# tt0111161                    The Shawshank Redemption (1994)  1994     9.2
# tt0110912                                Pulp Fiction (1994)  1994     9.0
# tt0137523                                  Fight Club (1999)  1999     8.8
# tt0133093                                  The Matrix (1999)  1999     8.7
# tt1375666                                   Inception (2010)  2010     8.9
# tt0109830                                Forrest Gump (1994)  1994     8.7
# tt0169547                             American Beauty (1999)  1999     8.6
# tt0499549                                      Avatar (2009)  2009     8.1
# tt0108052                            Schindler's List (1993)  1993     8.9
# tt0080684  Star Wars: Episode V - The Empire Strikes Back...  1980     8.8
#
#             votes     length                            genres
# id
# tt0111161  619479  142 mins.                       Crime|Drama
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, tt0111161 to tt0279977
# Data columns (total 6 columns):
# title     10000 non-null object
# year      10000 non-null int64
# rating    10000 non-null float64
# votes     10000 non-null int64
# length    10000 non-null object
# genres    9999 non-null object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 546.9+ KB

# %%
data.describe()
# Out:
#                year        rating          votes
# count  10000.000000  10000.000000   10000.000000
# mean    1993.472800      6.386070   16604.012800
# std       14.829924      1.189933   34563.459698
# min     1950.000000      1.500000    1356.000000
# 25%     1986.000000      5.700000    2333.750000
# 50%     1998.000000      6.600000    4980.500000
# 75%     2005.000000      7.200000   15277.750000
# max     2011.000000      9.200000  619479.000000

# %%
data.describe(include='all')
# Out:
#                title          year        rating          votes    length  \
# count          10000  10000.000000  10000.000000   10000.000000     10000
# unique          9998           NaN           NaN            NaN       162
# top     Noise (2007)           NaN           NaN            NaN  90 mins.
# freq               2           NaN           NaN            NaN       340
# mean             NaN   1993.472800      6.386070   16604.012800       NaN
# std              NaN     14.829924      1.189933   34563.459698       NaN
# min              NaN   1950.000000      1.500000    1356.000000       NaN
# 25%              NaN   1986.000000      5.700000    2333.750000       NaN
# 50%              NaN   1998.000000      6.600000    4980.500000       NaN
# 75%              NaN   2005.000000      7.200000   15277.750000       NaN
# max              NaN   2011.000000      9.200000  619479.000000       NaN
#
#        genres
# count    9999
# unique   1643
# top     Drama
# freq      711
# ...

# %% [markdown]
# # exporting Data

# %%
data.to_csv('test.csv', header=True, index=True, sep=",")

# %% [markdown]
# # Sorting Data

# %%
data.sort_values(by = 'rating')
# Out:
#                                            title  year  rating   votes  \
# id
# tt0270846    Superbabies: Baby Geniuses 2 (2004)  2004     1.5   13196
# tt0059464                 Monster a-Go Go (1965)  1965     1.5    3255
# tt0364986                    Ben & Arthur (2002)  2002     1.5    4675
# tt0421051               Daniel the Wizard (2004)  2004     1.5    8271
# tt1309000                      Dream Well (2009)  2009     1.5    2848
# ...                                          ...   ...     ...     ...
# tt0071562          The Godfather: Part II (1974)  1974     9.0  291169
# tt0060196  The Good, the Bad and the Ugly (1966)  1966     9.0  195238
# tt0110912                    Pulp Fiction (1994)  1994     9.0  490065
# tt0068646                   The Godfather (1972)  1972     9.2  474189
# tt0111161        The Shawshank Redemption (1994)  1994     9.2  619479
#
#               length                              genres
# id
# ...

# %%
data.sort_values(by = 'year')
# Out:
#                                                       title  year  rating  \
# id
# tt0042994                               Stage Fright (1950)  1950     7.0
# tt0042179  Abbott and Costello in the Foreign Legion (1950)  1950     6.3
# tt0042327                       Cheaper by the Dozen (1950)  1950     6.9
# tt0042286                               Broken Arrow (1950)  1950     7.2
# tt0042906                                   La Ronde (1950)  1950     7.6
# ...                                                     ...   ...     ...
# tt1161864                                   The Rite (2011)  2011     6.0
# tt1396218                      Mr. Popper's Penguins (2011)  2011     5.9
# tt1735485                           The Tunnel Movie (2011)  2011     6.0
# tt0893412                         From Prada to Nada (2011)  2011     4.8
# tt1499658                            Horrible Bosses (2011)  2011     7.6
#
#            votes     length                 genres
# id
# ...

# %%
# in descending order
data.sort_values(by = 'rating', ascending = False)
# Out:
#                                            title  year  rating   votes  \
# id
# tt0111161        The Shawshank Redemption (1994)  1994     9.2  619479
# tt0068646                   The Godfather (1972)  1972     9.2  474189
# tt0060196  The Good, the Bad and the Ugly (1966)  1966     9.0  195238
# tt0110912                    Pulp Fiction (1994)  1994     9.0  490065
# tt0252487                Outrageous Class (1975)  1975     9.0    9823
# ...                                          ...   ...     ...     ...
# tt0364986                    Ben & Arthur (2002)  2002     1.5    4675
# tt0060753       Night Train to Mundo Fine (1966)  1966     1.5    3542
# tt0421051               Daniel the Wizard (2004)  2004     1.5    8271
# tt0059464                 Monster a-Go Go (1965)  1965     1.5    3255
# tt0060666        Manos: The Hands of Fate (1966)  1966     1.5   20927
#
#               length                              genres
# id
# ...

# %% [markdown]
# # Creating DataFrames from Scratch

# %%
sample_data = {
    'tv': [230, 204, 250],
    'radio': [37, 39, 45],
    'news': [69, 450, 78],
    'sales': [1, 34, 128]
}

# %%
d2 = pd.DataFrame(sample_data)

# %%
d2.head()
# Out:
#     tv  radio  news  sales
# 0  230     37    69      1
# 1  204     39   450     34
# 2  250     45    78    128

# %%
del d2

# %% [markdown]
# # Selecting Data

# %%
data['title']
# Out:
# id
# tt0111161    The Shawshank Redemption (1994)
# tt0110912                Pulp Fiction (1994)
# tt0137523                  Fight Club (1999)
# tt0133093                  The Matrix (1999)
# tt1375666                   Inception (2010)
#                           ...
# tt0807721                     Meduzot (2007)
# tt0339642              Daltry Calhoun (2005)
# tt0060880      The Quiller Memorandum (1966)
# tt0152836                        Taal (1999)
# tt0279977              The Navigators (2001)
# Name: title, Length: 10000, dtype: object

# %%
data['title'].head()
# Out:
# id
# tt0111161    The Shawshank Redemption (1994)
# tt0110912                Pulp Fiction (1994)
# tt0137523                  Fight Club (1999)
# tt0133093                  The Matrix (1999)
# tt1375666                   Inception (2010)
# Name: title, dtype: object

# %%
data[['title', 'year']]
# Out:
#                                      title  year
# id
# tt0111161  The Shawshank Redemption (1994)  1994
# tt0110912              Pulp Fiction (1994)  1994
# tt0137523                Fight Club (1999)  1999
# tt0133093                The Matrix (1999)  1999
# tt1375666                 Inception (2010)  2010
# ...                                    ...   ...
# tt0807721                   Meduzot (2007)  2007
# tt0339642            Daltry Calhoun (2005)  2005
# tt0060880    The Quiller Memorandum (1966)  1966
# tt0152836                      Taal (1999)  1999
# tt0279977            The Navigators (2001)  2001
#
# [10000 rows x 2 columns]

# %%
data['rating'].mean()
# Out:
# 6.386069999999981

# %%
data['genres'].unique()
# Out:
# array(['Crime|Drama', 'Crime|Thriller', 'Drama|Mystery|Thriller', ...,
#        'Drama|War|Adventure|Romance', 'Western|Sci-Fi|Thriller',
#        'Adventure|Comedy|Drama|War'], dtype=object)

# %%
data['rating'].max()
# Out:
# 9.2

# %%
data['rating'].value_counts()
# Out:
# 6.8    401
# 7.1    401
# 7.2    386
# 6.7    384
# 7.0    382
#       ...
# 1.5      7
# 1.6      6
# 8.9      5
# 9.0      4
# 9.2      2
# Name: rating, Length: 77, dtype: int64

# %%
data['genres'].value_counts()
# Out:
# Drama                                                     711
# Comedy                                                    470
# Drama|Romance                                             395
# Comedy|Drama                                              388
# Comedy|Drama|Romance                                      367
#                                                          ...
# Comedy|Musical|Fantasy|Mystery                              1
# Crime|Drama|Fantasy|Horror|Sci-Fi|Thriller                  1
# Drama|Film-Noir|Mystery                                     1
# Action|Adventure|Crime|Mystery|Romance                      1
# Animation|Action|Crime|Family|Mystery|Romance|Thriller      1
# Name: genres, Length: 1643, dtype: int64

# %%
data['year'].value_counts()
# Out:
# 2006    502
# 2007    496
# 2008    481
# 2005    439
# 2004    430
#        ...
# 1961     43
# 1954     39
# 1952     37
# 1951     32
# 1950     31
# Name: year, Length: 62, dtype: int64

# %%
data['rating'].value_counts().sort_index()
# Out:
# 1.5     7
# 1.6     6
# 1.7    12
# 1.8    12
# 1.9     9
#        ..
# 8.7    13
# 8.8     9
# 8.9     5
# 9.0     4
# 9.2     2
# Name: rating, Length: 77, dtype: int64

# %%
data['rating'].value_counts().sort_index(ascending=False)
# Out:
# 9.2     2
# 9.0     4
# 8.9     5
# 8.8     9
# 8.7    13
#        ..
# 1.9     9
# 1.8    12
# 1.7    12
# 1.6     6
# 1.5     7
# Name: rating, Length: 77, dtype: int64

# %% [markdown]
# # Selecting Data

# %%
data['rating'].value_counts()
# Out:
# 6.8    401
# 7.1    401
# 7.2    386
# 6.7    384
# 7.0    382
#       ...
# 1.5      7
# 1.6      6
# 8.9      5
# 9.0      4
# 9.2      2
# Name: rating, Length: 77, dtype: int64

# %%
data['year'].value_counts().sort_index(ascending=False)
# Out:
# 2011     98
# 2010    315
# 2009    417
# 2008    481
# 2007    496
#        ...
# 1954     39
# 1953     47
# 1952     37
# 1951     32
# 1950     31
# Name: year, Length: 62, dtype: int64

# %%
data['year'].unique()
# Out:
# array([1994, 1999, 2010, 2009, 1993, 1980, 2005, 1995, 1991, 1997, 2003,
#        1990, 2006, 1992, 2008, 1972, 2001, 2002, 1977, 2000, 1998, 1974,
#        1981, 2004, 1975, 1985, 1983, 2007, 1971, 1988, 1984, 1982, 1986,
#        1987, 1979, 1989, 1966, 1996, 1976, 1968, 1964, 1960, 1957, 1954,
#        1973, 1959, 1958, 1978, 1962, 1967, 2011, 1963, 1969, 1950, 1952,
#        1965, 1970, 1961, 1951, 1953, 1956, 1955], dtype=int64)

# %% [markdown]
# # Plotting

# %%
# %matplotlib inline

# %%
data.plot()

# %%
data.plot(kind='scatter', x='rating', y='votes')

# %%
data.plot(kind='scatter', x='rating', y='votes', alpha=0.3)

# %%
data['rating'].plot(kind='hist')

# %% [markdown]
# ## seaborn

# %%
import seaborn as sns

# %%
sns.lmplot(x='rating', y='votes', data=data)

# %%
sns.pairplot(data)

# %% [markdown]
# # Ordinary Least Squares Regression

# %%
import statsmodels.api as sm

# %%
results = sm.OLS(data['votes'], data['rating']).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  votes   R-squared (uncentered):                   0.221
# Model:                            OLS   Adj. R-squared (uncentered):              0.220
# Method:                 Least Squares   F-statistic:                              2829.
# Date:                Thu, 19 Dec 2019   Prob (F-statistic):                        0.00
# Time:                        12:18:30   Log-Likelihood:                     -1.1849e+05
# No. Observations:               10000   AIC:                                  2.370e+05
# Df Residuals:                    9999   BIC:                                  2.370e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
results

# %% [markdown]
# # Advance Data Selection

# %%
data[data['year'] > 1995].head()
# Out:
#                             title  year  rating   votes     length  \
# id
# tt0137523       Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093       The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666        Inception (2010)  2010     8.9  385149  148 mins.
# tt0169547  American Beauty (1999)  1999     8.6  338332  122 mins.
# tt0499549           Avatar (2009)  2009     8.1  336855  162 mins.
#
#                                      genres
# id
# tt0137523            Drama|Mystery|Thriller
# tt0133093           Action|Adventure|Sci-Fi
# tt1375666  Action|Adventure|Sci-Fi|Thriller
# tt0169547                             Drama
# tt0499549   Action|Adventure|Fantasy|Sci-Fi

# %%
data[data['year'] == 1997]
# Out:
#                                     title  year  rating   votes     length  \
# id
# tt0120338                  Titanic (1997)  1997     7.4  284245  194 mins.
# tt0119488        L.A. Confidential (1997)  1997     8.4  187115  138 mins.
# tt0119217        Good Will Hunting (1997)  1997     8.1  180850  126 mins.
# tt0119116        The Fifth Element (1997)  1997     7.5  151108  126 mins.
# tt0119654             Men in Black (1997)  1997     7.0  138013   98 mins.
# ...                                   ...   ...     ...     ...        ...
# tt0115985              Crossworlds (1997)  1997     5.1    1425   90 mins.
# tt0120303  Telling Lies in America (1997)  1997     6.2    1417  101 mins.
# tt0120211          Still Breathing (1997)  1997     6.5    1397  109 mins.
# tt0118785             Budbringeren (1997)  1997     6.8    1385   83 mins.
# tt0120540                 Yes Boss (1997)  1997     6.8    1384  163 mins.
#
#                                     genres
# id
# ...

# %%
data[(data['year'] > 1996) & (data['year'] < 2000)].sort_values(by='rating', ascending=False).head(3)
# Out:
#                             title  year  rating   votes     length  \
# id
# tt0137523       Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093       The Matrix (1999)  1999     8.7  448114  136 mins.
# tt0169547  American Beauty (1999)  1999     8.6  338332  122 mins.
#
#                             genres
# id
# tt0137523   Drama|Mystery|Thriller
# tt0133093  Action|Adventure|Sci-Fi
# tt0169547                    Drama

# %% [markdown]
# # Grouping

# %%
data.groupby(data['year'])['rating'].mean()
# Average Rating of movies per year
# Out:
# year
# 1950    7.545161
# 1951    7.478125
# 1952    7.475676
# 1953    7.106383
# 1954    7.371795
#           ...
# 2007    6.303831
# 2008    6.275260
# 2009    6.287290
# 2010    6.340635
# 2011    6.357143
# Name: rating, Length: 62, dtype: float64

# %%
data.groupby(data['year'])['rating'].max()
# Out:
# year
# 1950    8.7
# 1951    8.3
# 1952    8.4
# 1953    8.3
# 1954    8.8
#        ...
# 2007    8.3
# 2008    8.9
# 2009    8.4
# 2010    8.9
# 2011    8.6
# Name: rating, Length: 62, dtype: float64

# %% [markdown]
# # Challenge

# %% [markdown]
# 1. What was the highest scoring movie in 1996?
# 2. In what year was the highest rated movie of all time made?
# 3. What five movies have the most votes ever?
# 4. what year in the 1960s had the highest average movie rating?

# %%
# 1) What was the highest scoring movie in 1996?
data[data['year'] == 1996]['rating'].max()
# Out:
# 8.3

# %%
# 2) In what year was the highest rated movie of all time made?
data[data['rating'] == data['rating'].max()]
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0068646             The Godfather (1972)  1972     9.2  474189  175 mins.
#
#                 genres
# id
# tt0111161  Crime|Drama
# tt0068646  Crime|Drama

# %%
# 3. What five movies have the most votes ever?
data.groupby(by='votes').head()
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
# ...                                    ...   ...     ...     ...        ...
# tt0807721                   Meduzot (2007)  2007     7.0    1357   78 mins.
# tt0339642            Daltry Calhoun (2005)  2005     5.2    1357  100 mins.
# tt0060880    The Quiller Memorandum (1966)  1966     6.5    1356  104 mins.
# tt0152836                      Taal (1999)  1999     6.5    1356  179 mins.
# tt0279977            The Navigators (2001)  2001     6.9    1356   96 mins.
#
#                                      genres
# id
# ...

# %%
# 4. what year in the 1960s had the highest average movie rating?
data[(data['year'] >= 1960) & (data['year'] < 1970)].groupby(data['year']).mean()
# Out:
#         year    rating         votes
# year
# 1960  1960.0  7.247917  10692.104167
# 1961  1961.0  7.195349   7551.651163
# 1962  1962.0  7.349057  10355.943396
# 1963  1963.0  7.103922   8699.352941
# 1964  1964.0  6.865217   8543.318841
# 1965  1965.0  6.996875   5933.921875
# 1966  1966.0  6.895652   7826.028986
# 1967  1967.0  7.169091   8904.909091
# 1968  1968.0  6.967213  12314.229508
# 1969  1969.0  7.011321   7267.150943

# %% [markdown]
# # Solution by Instructor

# %%
# Answer 1

data[data['year'] == 1996].sort_values(by='rating', ascending=False).head()
# Out:
#                            title  year  rating   votes     length  \
# id
# tt0116282           Fargo (1996)  1996     8.3  187498   98 mins.
# tt0116231      The Bandit (1996)  1996     8.3   13288  121 mins.
# tt0117951   Trainspotting (1996)  1996     8.2  175993   94 mins.
# tt0117666     Sling Blade (1996)  1996     8.0   44316  135 mins.
# tt0117589  Secrets & Lies (1996)  1996     8.0   15435  142 mins.
#
#                                         genres
# id
# tt0116282                 Crime|Drama|Thriller
# tt0116231  Action|Crime|Drama|Romance|Thriller
# tt0117951                          Crime|Drama
# tt0117666                                Drama
# tt0117589                         Comedy|Drama

# %%
# Answer 2

data.sort_values(by='rating', ascending=False)
# Out:
#                                            title  year  rating   votes  \
# id
# tt0111161        The Shawshank Redemption (1994)  1994     9.2  619479
# tt0068646                   The Godfather (1972)  1972     9.2  474189
# tt0060196  The Good, the Bad and the Ugly (1966)  1966     9.0  195238
# tt0110912                    Pulp Fiction (1994)  1994     9.0  490065
# tt0252487                Outrageous Class (1975)  1975     9.0    9823
# ...                                          ...   ...     ...     ...
# tt0364986                    Ben & Arthur (2002)  2002     1.5    4675
# tt0060753       Night Train to Mundo Fine (1966)  1966     1.5    3542
# tt0421051               Daniel the Wizard (2004)  2004     1.5    8271
# tt0059464                 Monster a-Go Go (1965)  1965     1.5    3255
# tt0060666        Manos: The Hands of Fate (1966)  1966     1.5   20927
#
#               length                              genres
# id
# ...

# %%
data[data['rating'] == data['rating'].max()] 
# Same as Instructor
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0068646             The Godfather (1972)  1972     9.2  474189  175 mins.
#
#                 genres
# id
# tt0111161  Crime|Drama
# tt0068646  Crime|Drama

# %%
# Answer 3
data.sort_values(by='votes', ascending=False).head()
# data.groupby(by='votes').head() my solution
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0468569           The Dark Knight (2008)  2008     8.9  555122  152 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0068646             The Godfather (1972)  1972     9.2  474189  175 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
#
#                                 genres
# id
# tt0111161                  Crime|Drama
# tt0468569  Action|Crime|Drama|Thriller
# tt0110912               Crime|Thriller
# tt0068646                  Crime|Drama
# tt0137523       Drama|Mystery|Thriller

# %%
data.groupby(by='votes').head(1)
# which is wrong
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
# ...                                    ...   ...     ...     ...        ...
# tt0388364                  Red Dust (2004)  2004     6.8    1360  110 mins.
# tt0094642           American Gothic (1988)  1988     5.1    1359   00 mins.
# tt0329393         Mr. and Mrs. Iyer (2002)  2002     7.9    1358  120 mins.
# tt0110064             House Party 3 (1994)  1994     3.1    1357  100 mins.
# tt0878674                    Garage (2007)  2007     6.9    1356   00 mins.
#
#                                      genres
# id
# ...

# %%
# Answer 4
data[(data['year'] >= 1960) & (data['year'] < 1970)].groupby(data['year'])['rating'].mean()
# Out:
# year
# 1960    7.247917
# 1961    7.195349
# 1962    7.349057
# 1963    7.103922
# 1964    6.865217
# 1965    6.996875
# 1966    6.895652
# 1967    7.169091
# 1968    6.967213
# 1969    7.011321
# Name: rating, dtype: float64

# %% [markdown]
# # Cleaning Data

# %%
data['formatted title'] = data['title'].str.split(' \(').str.get(0)  #.str[0]

# %%
data.head()
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres           formatted title
# id
# tt0111161                       Crime|Drama  The Shawshank Redemption
# tt0110912                    Crime|Thriller              Pulp Fiction
# tt0137523            Drama|Mystery|Thriller                Fight Club
# tt0133093           Action|Adventure|Sci-Fi                The Matrix
# tt1375666  Action|Adventure|Sci-Fi|Thriller                 Inception

# %%
data['formatted length'] = data['length'].str.split(' m').str[0]
data.head()
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres           formatted title  \
# id
# tt0111161                       Crime|Drama  The Shawshank Redemption
# tt0110912                    Crime|Thriller              Pulp Fiction
# tt0137523            Drama|Mystery|Thriller                Fight Club
# tt0133093           Action|Adventure|Sci-Fi                The Matrix
# tt1375666  Action|Adventure|Sci-Fi|Thriller                 Inception
#
#           formatted length
# id
# tt0111161              142
# ...

# %%
sns.pairplot(data)

# %%
data[data['length'] == 0]
# Out:
# Empty DataFrame
# Columns: [title, year, rating, votes, length, genres, formatted title, formatted length]
# Index: []

# %%
header = ['id', 'title', 'year', 'rating', 'votes', 'length', 'genres']
# index_col = 0 will make the first row as id
data1 = pd.read_csv('imdb_top_10000.txt', sep = '\t', names = header, index_col = 0)

# %%
data1['formatted length'] = data1['length'].str.split(' m').str.get(0)

# %%
data1.head()
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres formatted length
# id
# tt0111161                       Crime|Drama              142
# tt0110912                    Crime|Thriller              154
# tt0137523            Drama|Mystery|Thriller              139
# tt0133093           Action|Adventure|Sci-Fi              136
# tt1375666  Action|Adventure|Sci-Fi|Thriller              148

# %%
data1[data1['formatted length'] == 0]
# Out:
# Empty DataFrame
# Columns: [title, year, rating, votes, length, genres, formatted length]
# Index: []

# %%
data['formatted genres'] = data['genres'].str.split('|')

# %%
data.head()
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres           formatted title  \
# id
# tt0111161                       Crime|Drama  The Shawshank Redemption
# tt0110912                    Crime|Thriller              Pulp Fiction
# tt0137523            Drama|Mystery|Thriller                Fight Club
# tt0133093           Action|Adventure|Sci-Fi                The Matrix
# tt1375666  Action|Adventure|Sci-Fi|Thriller                 Inception
#
#           formatted length                       formatted genres
# id
# ...

# %%
# data.gov to work on govt data
